# %%
# Dependencies 
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
import pandas as pd

# %%
browser = Browser("chrome", executable_path="chromedriver", headless=True)

# %% [markdown]
# ### WineBusiness.com

# %%
# URL of wine-seacher
url = 'https://www.winebusiness.com/news'
browser.visit(url)

# %%
# HTML object
html = browser.html
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(html, 'html.parser')

# %%
# Return title, and preview

news_title = soup.find('div', class_='wb-section-item-title').text
news_p = soup.find('p', class_='wb-break-word').text

to_link = soup.find('div', class_='wb-section-item-title')
link = to_link.a['href']

print(f' Article Title: {news_title}')
print(f' Article Summary: {news_p}')
print('--------------------------')
print(f' Article Link: https://www.winebusiness.com{link}')
# Out:
#  Article Title: Winejobs.com Releases 2020 HR SUMMIT Replays
#  Article Summary: Focused on recruiting, retention and development, the Winejobs.com HR SUMMIT, held Nov. 10, 2020 via Zoom, is the forum for wine industry HR professionals. Winejobs.com, which is owned and operated by Wine Business Monthly, is providing all the sessions online, and for free, in the hope that it helps wine businesses thrive.
# --------------------------
#  Article Link: https://www.winebusiness.com/news/?go=getNewsLink&dataId=238447

# %%
# Define URL
url = 'https://www.winebusiness.com/classifieds/winejobs/'
tables = pd.read_html(url)
tables
# Out:
# [                                         Title                  Company  \
#  0   HR Generalist, Bilingual (Spanish/English)  Wilson Artisan Wineries
#  1                         Customer Service Rep        Last Bottle Wines
#  2                                    Enologist       Boisset Collection
#  3                 Retail & Hospitality Manager  Sequoia Grove Vineyards
#  4                         Hospitality Director        Ram's Gate Winery
#  5  Vice President Division Manager; Fl, Al, MS             Weed Cellars
#  6                            Tasting Room Host        Brian Arden Wines
#  7              Trade Ambassador for The Mascot        Pacific Union Co.
#  8                   The Mascot Trade Associate        Pacific Union Co.
#  9          Compliance and Tax Auditing Manager    Monterey Wine Company
#
#              Location
#  0    Geyserville, CA
#  1           Napa, CA
#  2     St. Helena, CA
#  3           Napa, CA
#  4         Sonoma, CA
#  5            ANY, FL
# ...

# %%
# Save table with most recent listings 
recent_listings = tables[1]
recent_listings
# Out:
#                                                 Title  \
# 0   Enologist/Assistant Winemaker/Associate Winemaker
# 1                                 Delivery Supervisor
# 2                      Membership Development Manager
# 3         Distribution Center Associate - Night Shift
# 4           Distribution Center Associate - Day Shift
# 5                Senior Director, Accounts Receivable
# 6       Manager, Sensory Projects (Woodbridge Winery)
# 7   Vintrace Head of Marketing & Coms USA Or Austr...
# 8                                    Catering Manager
# 9                                Social Media Manager
# 10                          Creative Services Manager
# 11                                       Truck Driver
# 12                                   Cellar II Worker
# 13                   Marketing / Social Media Manager
# 14         Assistant Manager of Sales and Hospitality
# 15           XXI Wine and Spirits - Naples Sales Reps
# ...

# %% [markdown]
# ## Wine Folly Learn about Wines

# %%
# URL Wine Follow
url = 'https://winefolly.com/wines/'
browser.visit(url)

# %%
# HTML object
html = browser.html
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(html, 'html.parser')

# %%
# Find image url 
dict = {}
resources = soup.find_all('div', class_='col-md-4 col-sm-6 grape')

# %%
for resource in resources:
    wine_link = resource.a['href']
    
    wine = resource('img')[1]
    wine_image = wine['src']
    
     # Update dictionary with new information
    dict.update({wine_image:wine_link})
    
    print('Adding to dictionary')
    print(wine_image)
    print(wine_link)
    print('-------')
# Out:
# Adding to dictionary
# https://media.winefolly.com/Bandol-wine-tasting-WineFolly-768x576.jpg
# https://winefolly.com/wines/bandol-red/
# -------
# Adding to dictionary
# https://media.winefolly.com/Banyuls-wine-tasting-WineFolly-768x576.jpg
# https://winefolly.com/wines/banyuls/
# -------
# Adding to dictionary
# https://media.winefolly.com/Barolo-wine-tasting-WineFolly-768x576.jpg
# https://winefolly.com/wines/barolo/
# -------
# Adding to dictionary
# https://media.winefolly.com/Bordeaux-Blend-White-wine-tasting-WineFolly-768x576.jpg
# https://winefolly.com/wines/bordeaux-blend-white/
# -------
# Adding to dictionary
# https://media.winefolly.com/Brunello-di-Montalcino-wine-tasting-WineFolly-768x576.jpg
# https://winefolly.com/wines/brunello-di-montalcino/
# -------
# Adding to dictionary
# https://media.winefolly.com/Cap-Classique-wine-tasting-WineFolly-768x576.jpg
# https://winefolly.com/wines/cap-classique/
# -------
# Adding to dictionary
# ...
